# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 300%">Projet INF473V</div>                                                        <br />
# <div style="text-align: center; font-weight: bold; font-size: 180%">Processing - ResNet-50 - 4 classes </div>                                                        <br />
# <div style="text-align: center; font-size: 150%">École Polytechnique, juin 2020</div><br />
# <div style="text-align: center; font-size: 120%">Youssef Allouah et Paul Calot</div>**

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
import torchvision
import matplotlib.pyplot as plt # to show img
from tqdm.notebook import tqdm
import torch.nn as nn
from matplotlib.lines import Line2D

# %%
root_dir = ''
trset = torch.load(root_dir + "datasets_6")
tsset = torch.load(root_dir + "testing_dataset_60")

# %%
class tweakedDataset(Dataset):
    
    def __init__(self, dts, cuda=True):
        self.dts = dts
        self.df = pd.DataFrame(np.zeros(dts.__len__()))
        self.cuda=cuda
        
    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self, idx):
        images, labels = self.dts.__getitem__(idx)
        if self.cuda:
            images = images.type(torch.cuda.FloatTensor)
            labels = labels.type(torch.cuda.LongTensor)
        else:
            images = images.type(torch.FloatTensor)
            labels = labels.type(torch.LongTensor)            
        return images, labels

training_set = tweakedDataset(trset)#, cuda=False)
testing_set = tweakedDataset(tsset)#, cuda=False)

# %%
# print proportion
def show_proportion(training_set, testing_set):
    train_size = len(training_set)
    test_size = len(testing_set)
    per_train = [0,0,0,0]
    per_test = [0,0,0,0]
    for k in range(train_size):
      per_train[int(training_set[k][1].item())]+=1

    for k in range(test_size):
      per_test[int(testing_set[k][1].item())]+=1

    for k in range(4):
      per_train[k] = round(per_train[k]/train_size,4)
      per_test[k] = round(per_test[k]/test_size,4)

    df = pd.DataFrame({'classes':['healthy', 'multiple', 'rust','scab'], 'quantity':per_train})
    ax1 = df.plot.bar(x='classes', y='quantity', color = ['g', 'r', 'brown', 'k'], rot = 0)
    ax1.set_title('Training set repartition')
    fig1 = ax1.get_figure()
    for p in ax1.patches:
        ax1.annotate(str(p.get_height()), (p.get_x()*1.005, p.get_height() * 1.005))

    df = pd.DataFrame({'classes':['healthy', 'multiple', 'rust','scab'], 'quantity':per_test})
    ax2 = df.plot.bar(x='classes', y='quantity', color = ['g', 'r', 'brown', 'k'], rot = 0)
    ax2.set_title('Testing set repartition')
    fig2 = ax2.get_figure()

    for p in ax2.patches:
        ax2.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.006))

    fig1.savefig('train_repartition.png', dpi=400)
    fig2.savefig('test_repartition.png', dpi=400)

    print(f'Size of training set: {train_size} \nSize of testing set: {test_size}')

show_proportion(training_set, testing_set)

# %%
class EarlyStopping:
# The following code was inspired from this open-source project: https://colab.research.google.com/github/sanchit2843/MLBasics/blob/master/IntelClassificationKaggle/Pytorch%20transfer%20learning%20tutorial%20%5B93%25acc%5D.ipynb
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'resnet50checkpoint.pt')
        self.val_loss_min = val_loss

def accuracy(net, test_loader, cuda=True):
  net.eval()
  correct = 0
  total = 0
  loss = 0
  with torch.no_grad():
      for data in test_loader:
          images, labels = data
          if cuda:
            images = images.type(torch.cuda.FloatTensor)
            labels = labels.type(torch.cuda.LongTensor)
          outputs = net(images)
          
          _, predicted = torch.max(outputs.data, 1)
#           target = torch.argmax(labels, dim=1)
#           loss+= criterion(outputs, target).item()
          loss+= criterion(outputs, labels).item()
          total += labels.size(0)
#           correct += (predicted == target).sum().item()
          correct += (predicted == labels).sum().item()
  net.train()
  print('Accuracy of the network on the test images: %d %%' % (
      100 * correct / total))
  return (100.0 * correct / total, float(loss)/total)
  # return 100.0 * correct / total

# The following functions for gradient flow plotting were inspired from the following open-source project: https://github.com/alwynmathew/gradflow-check
def plot_grad_flow(named_parameters):
    '''Plots the gradients flowing through different layers in the net during training.
    Can be used for checking for possible gradient vanishing / exploding problems.
    
    Usage: Plug this function in Trainer class after loss.backwards() as 
    "plot_grad_flow(self.model.named_parameters())" to visualize the gradient flow'''
    ave_grads = []
    max_grads= []
    layers = []
    for n, p in named_parameters:
        if(p.requires_grad) and ("bias" not in n):
            layers.append(n)
            ave_grads.append(p.grad.abs().mean())
            max_grads.append(p.grad.abs().max())
    plt.bar(np.arange(len(max_grads)), max_grads, alpha=0.1, lw=1, color="c")
    plt.bar(np.arange(len(max_grads)), ave_grads, alpha=0.1, lw=1, color="b")
    plt.hlines(0, 0, len(ave_grads)+1, lw=2, color="k" )
    plt.xticks(range(0,len(ave_grads), 1), layers, rotation="vertical")
    plt.xlim(left=0, right=len(ave_grads))
    plt.ylim(bottom = -0.001, top=0.02) # zoom in on the lower gradient regions
    plt.xlabel("Layers")
    plt.ylabel("average gradient")
    plt.title("Gradient flow")
    plt.grid(True)
    plt.legend([Line2D([0], [0], color="c", lw=4),
                Line2D([0], [0], color="b", lw=4),
                Line2D([0], [0], color="k", lw=4)], ['max-gradient', 'mean-gradient', 'zero-gradient'])    

def plot_grad_flow2(named_parameters):
    ave_grads = []
    layers = []
    for n, p in named_parameters:
        if(p.requires_grad) and ("bias" not in n):
            layers.append(n)
            ave_grads.append(p.grad.abs().mean())
    plt.plot(ave_grads, alpha=0.3, color="b")
    plt.hlines(0, 0, len(ave_grads)+1, linewidth=1, color="k" )
    plt.xticks(range(0,len(ave_grads), 1), layers, rotation="vertical")
    plt.xlim(xmin=0, xmax=len(ave_grads))
    plt.xlabel("Layers")
    plt.ylabel("average gradient")
    plt.title("Gradient flow")
    plt.grid(True)
    
def smartrain(net, optimizer, train_loader, test_loader, loss,  n_epoch = 5,
          train_acc_period = 100,
          test_acc_period = 1,
          cuda=True,
          patience=None):
  loss_train = []
  acc_train = []
  loss_test = []
  acc_test = []
  total = 0
  if(patience!=None):
      earlystop = EarlyStopping(patience = patience,verbose = True)
  for epoch in range(n_epoch):  # loop over the dataset multiple times
      running_loss = 0.0
      running_acc = 0.0
      for i, data in enumerate(train_loader, 0):
          # get the inputs
          inputs, labels = data
          if cuda:
            inputs = inputs.type(torch.cuda.FloatTensor)
            labels = labels.type(torch.cuda.LongTensor)
          # print(inputs.shape)
          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
#           target = torch.argmax(labels, dim=1)
          loss = criterion(outputs, labels)
#           loss = criterion(outputs, target)
          loss.backward()
        
          plot_grad_flow2(net.named_parameters())
        
          optimizer.step()
          total += labels.size(0)
          # print statistics
          running_loss = 0.33*loss.item()/labels.size(0) + 0.66*running_loss

          _, predicted = torch.max(outputs.data, 1)
#           target = torch.argmax(labels, dim=1)
#           correct = (predicted == target).sum().item()/labels.size(0)
          correct = (predicted == labels).sum().item()/labels.size(0)
          running_acc = 0.33*correct + 0.66*running_acc
          if i % train_acc_period == train_acc_period-1:
            print('[%d, %5d] loss: %.3f' %(epoch + 1, i + 1, running_loss))
            print('[%d, %5d] acc: %.3f' %(epoch + 1, i + 1, running_acc))
            running_loss = 0.0
            total = 0
            # break
      if epoch % test_acc_period == test_acc_period-1:
          cur_acc, cur_loss = accuracy(net, test_loader, cuda=cuda)
          loss_test.append(cur_loss)
          acc_test.append(cur_acc)
          print('[%d] loss: %.3f' %(epoch + 1, cur_loss))
          print('[%d] acc: %.3f' %(epoch + 1, cur_acc))
          earlystop(cur_loss,net)
        
          # training set
          cur_acc, cur_loss = accuracy(net, train_loader, cuda=cuda)
          acc_train.append(cur_acc)
          loss_train.append(cur_loss)

      if(earlystop.early_stop):
          print("Early stopping")
          net.load_state_dict(torch.load('./resnet50checkpoint.pt'))
          break
      
  print('Finished Training')
  return loss_train, acc_train, loss_test, acc_test

# %%
#statistical tools

# !pip install seaborn
import seaborn as sn
import pandas as pd
def confusion_matrix(model, dataloader, size = 4, name = "Test", cuda = True): # here there are four classe
      model.eval()
      mat = np.zeros((size,size))
      total = 0
      corr = 0
      qty = [0,0,0,0]
      for images, labels in dataloader:
        if cuda:
          images = images.type(torch.cuda.FloatTensor)
          labels = labels.type(torch.cuda.LongTensor)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        for k in range(labels.size(0)): # ground truth first (row) and then prediction (col)
         # print("Here : " +str(labels[k].item()) + " ; " + str(predicted[k].item()))
          if(labels[k].item() == predicted[k].item()):
            corr +=1
          mat[labels[k].item(),predicted[k].item()]+=1
          qty[labels[k].item()]+=1
      for k in range(size):
        mat[k] *= 1/qty[k]
       # mat[k][size] = qty[k]/total # to have the total of images that the given class represented in the testing dataset
      model.train()
      dataframe = pd.DataFrame(mat, index=['healthy', 'multiple', 'rust', 'scab'])

      ax = plt.axes()

      svm = sn.heatmap(dataframe, annot=True, ax= ax)
      ax.set_title('Accuracy ' + name + " : " + str(round(corr / total,3)))
      figure = svm.get_figure()    
      figure.savefig('conf_mat' + name +'.png', dpi=400)

def plot(loss_train, acc_train, loss_test, acc_test):
    fig, axes = plt.subplots(nrows=1, ncols=2)#, figsize=(5, 3))
    axes[0].plot(range(1,1+len(loss_train)),loss_train, label='Train', color='b')
    axes[0].plot(range(1,1+len(loss_test)),loss_test, label= 'Test', color='r')
    axes[0].set_title('Train and test loss')

    axes[1].plot(range(1,1+len(acc_train)),acc_train, label= 'Train', color='b')
    axes[1].plot(range(1,1+len(acc_test)),acc_test, label= 'Test', color='r')
    axes[1].set_title('Train and test accuracy')
    
    fig.savefig('resnet50_modelperformance.png', dpi=400)

# %%
# !pip install torchsummary
from torchsummary import summary
model=torchvision.models.resnet50(pretrained=True)
# summary(model.cuda(),(3,224,224))

# %%
model=torchvision.models.resnet50(pretrained=True)


def frzlays(model=model, choice = 'last'):
    m = 0
    n = 0
    for child in model.fc.children():
        for param in child.parameters():
            m+=1
    for child in model.children():
        for param in child.parameters():
            n+=1
    l = n-m
    print(f'Total number of layers: n={n}\nNumber of layers in classifier: m={m}\nNumber of layers in backbone: l={l}')
    if choice == 'all':
        #freeze all net
        return n
    if choice == 'verylast':
        #unfreeze very last fc layer only
        return n-1
    if choice == 'last':
        #unfreeze last fc layer only
        return n-2
    if choice == 'classifier':
        #unfreeze classifier
        return n-m
    if choice == '2/3':
        #freeze only 2/3 of backbone
        return 2*l//3
    if choice == '1/5':
        #freeze only 1/5 of backbone
        return l//5
    if choice == 'none':
        #freeze none
        return 0

# %%
def init_and_freeze(choice):
    model=torchvision.models.resnet50(pretrained=True)
    lin = model.fc
    new_lin = nn.Sequential(lin,nn.ReLU(),
                              nn.Dropout(p=0.5),
                              nn.Linear(1000,4, bias = True))

    model.fc = new_lin

    freeze_layers = frzlays(model=model, choice=choice)
    k=0 
    for child in model.children():
        for param in child.parameters():
          k += 1
          if(k < freeze_layers ):
              param.requires_grad = False
          else:
              param.requires_grad = True
    return model

model = init_and_freeze('all')
# Out:
# Total number of layers: n=163
# Number of layers in classifier: m=4
# Number of layers in backbone: l=159

# %%
# !pip install pytorch-lr-finder
from pytorch_lr_finder import LearningRateFinder
def find_lr(model, criterion, optimizer):
    lrf = LearningRateFinder(model.cuda(), criterion, optimizer)
    lrf.fit(train_loader)
    lrf.plot()
    lrf.reset()

# %% [markdown]
# # First choice of freezing

# %%
model = init_and_freeze('verylast')
print(summary(model.cuda(), (3, 224, 224)))
# Out:
# Total number of layers: n=163
# Number of layers in classifier: m=4
# Number of layers in backbone: l=159
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                 [-1, 1000]       2,049,000
#             ReLU-175                 [-1, 1000]               0
#          Dropout-176                 [-1, 1000]               0
#           Linear-177                    [-1, 4]           4,004
# ================================================================
# Total params: 25,561,036
# Trainable params: 4,004
# Non-trainable params: 25,557,032
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.57
# Params size (MB): 97.51
# Estimated Total Size (MB): 384.66
# ----------------------------------------------------------------
# None

# %%
num_epochs = 5
batch_size = 64
learning_rate = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

# %%
find_lr(model, criterion, optimizer)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#   )
# ) <class 'torchvision.models.resnet.ResNet'>

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 5,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# [1,    10] loss: 0.019
# [1,    10] acc: 0.439
# [1,    20] loss: 0.017
# [1,    20] acc: 0.470
# [1,    30] loss: 0.015
# [1,    30] acc: 0.559
# [1,    40] loss: 0.015
# [1,    40] acc: 0.565
# [1,    50] loss: 0.014
# [1,    50] acc: 0.599
# Accuracy of the network on the test images: 72 %
# [1] loss: 0.733
# [1] acc: 72.977
# Validation loss decreased (inf --> 0.733205).  Saving model ...
# Accuracy of the network on the test images: 70 %
# [2,    10] loss: 0.013
# [2,    10] acc: 0.604
# [2,    20] loss: 0.012
# [2,    20] acc: 0.655
# [2,    30] loss: 0.011
# [2,    30] acc: 0.661
# [2,    40] loss: 0.012
# [2,    40] acc: 0.652
# [2,    50] loss: 0.012
# [2,    50] acc: 0.652
# Accuracy of the network on the test images: 78 %
# [2] loss: 0.611
# [2] acc: 78.464
# Validation loss decreased (0.733205 --> 0.610991).  Saving model ...
# Accuracy of the network on the test images: 76 %
# [3,    10] loss: 0.010
# [3,    10] acc: 0.705
# [3,    20] loss: 0.012
# [3,    20] acc: 0.661
# [3,    30] loss: 0.011
# [3,    30] acc: 0.683
# [3,    40] loss: 0.012
# [3,    40] acc: 0.651
# [3,    50] loss: 0.012
# [3,    50] acc: 0.651
# Accuracy of the network on the test images: 77 %
# [3] loss: 0.604
# [3] acc: 77.915
# Validation loss decreased (0.610991 --> 0.604109).  Saving model ...
# Accuracy of the network on the test images: 78 %
# [4,    10] loss: 0.009
# [4,    10] acc: 0.713
# [4,    20] loss: 0.012
# [4,    20] acc: 0.677
# [4,    30] loss: 0.012
# [4,    30] acc: 0.637
# [4,    40] loss: 0.011
# [4,    40] acc: 0.675
# [4,    50] loss: 0.011
# [4,    50] acc: 0.687
# Accuracy of the network on the test images: 79 %
# [4] loss: 0.568
# [4] acc: 79.561
# Validation loss decreased (0.604109 --> 0.568106).  Saving model ...
# Accuracy of the network on the test images: 78 %
# [5,    10] loss: 0.010
# [5,    10] acc: 0.714
# [5,    20] loss: 0.011
# [5,    20] acc: 0.684
# [5,    30] loss: 0.010
# [5,    30] acc: 0.703
# [5,    40] loss: 0.012
# [5,    40] acc: 0.674
# [5,    50] loss: 0.012
# [5,    50] acc: 0.663
# Accuracy of the network on the test images: 79 %
# [5] loss: 0.586
# [5] acc: 79.150
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 80 %
# [6,    10] loss: 0.011
# [6,    10] acc: 0.686
# [6,    20] loss: 0.010
# [6,    20] acc: 0.701
# [6,    30] loss: 0.010
# [6,    30] acc: 0.695
# [6,    40] loss: 0.012
# [6,    40] acc: 0.696
# [6,    50] loss: 0.011
# [6,    50] acc: 0.674
# Accuracy of the network on the test images: 80 %
# [6] loss: 0.542
# [6] acc: 80.521
# Validation loss decreased (0.568106 --> 0.542419).  Saving model ...
# Accuracy of the network on the test images: 79 %
# [7,    10] loss: 0.012
# [7,    10] acc: 0.646
# [7,    20] loss: 0.010
# [7,    20] acc: 0.697
# [7,    30] loss: 0.010
# [7,    30] acc: 0.716
# [7,    40] loss: 0.011
# [7,    40] acc: 0.667
# [7,    50] loss: 0.010
# [7,    50] acc: 0.729
# Accuracy of the network on the test images: 78 %
# [7] loss: 0.600
# [7] acc: 78.738
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 80 %
# [8,    10] loss: 0.009
# [8,    10] acc: 0.748
# [8,    20] loss: 0.011
# [8,    20] acc: 0.716
# [8,    30] loss: 0.009
# [8,    30] acc: 0.725
# [8,    40] loss: 0.010
# [8,    40] acc: 0.707
# [8,    50] loss: 0.012
# [8,    50] acc: 0.659
# Accuracy of the network on the test images: 80 %
# [8] loss: 0.545
# [8] acc: 80.110
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 81 %
# [9,    10] loss: 0.009
# [9,    10] acc: 0.728
# [9,    20] loss: 0.010
# [9,    20] acc: 0.712
# [9,    30] loss: 0.011
# [9,    30] acc: 0.700
# [9,    40] loss: 0.010
# [9,    40] acc: 0.703
# [9,    50] loss: 0.010
# [9,    50] acc: 0.718
# Accuracy of the network on the test images: 79 %
# [9] loss: 0.543
# [9] acc: 79.698
# EarlyStopping counter: 3 out of 5
# Accuracy of the network on the test images: 82 %
# [10,    10] loss: 0.010
# [10,    10] acc: 0.724
# [10,    20] loss: 0.010
# [10,    20] acc: 0.682
# [10,    30] loss: 0.011
# [10,    30] acc: 0.705
# [10,    40] loss: 0.010
# [10,    40] acc: 0.727
# [10,    50] loss: 0.011
# [10,    50] acc: 0.676
# Accuracy of the network on the test images: 81 %
# [10] loss: 0.543
# [10] acc: 81.344
# EarlyStopping counter: 4 out of 5
# Accuracy of the network on the test images: 82 %
# [11,    10] loss: 0.010
# [11,    10] acc: 0.691
# [11,    20] loss: 0.010
# [11,    20] acc: 0.716
# [11,    30] loss: 0.010
# [11,    30] acc: 0.694
# [11,    40] loss: 0.009
# [11,    40] acc: 0.743
# [11,    50] loss: 0.010
# [11,    50] acc: 0.732
# Accuracy of the network on the test images: 81 %
# [11] loss: 0.532
# [11] acc: 81.070
# Validation loss decreased (0.542419 --> 0.532059).  Saving model ...
# Accuracy of the network on the test images: 82 %
# [12,    10] loss: 0.010
# [12,    10] acc: 0.683
# [12,    20] loss: 0.010
# [12,    20] acc: 0.731
# [12,    30] loss: 0.010
# [12,    30] acc: 0.730
# [12,    40] loss: 0.011
# [12,    40] acc: 0.696
# [12,    50] loss: 0.011
# [12,    50] acc: 0.699
# Accuracy of the network on the test images: 81 %
# [12] loss: 0.516
# [12] acc: 81.207
# Validation loss decreased (0.532059 --> 0.515983).  Saving model ...
# Accuracy of the network on the test images: 82 %
# [13,    10] loss: 0.010
# [13,    10] acc: 0.694
# [13,    20] loss: 0.010
# [13,    20] acc: 0.709
# [13,    30] loss: 0.011
# [13,    30] acc: 0.728
# [13,    40] loss: 0.009
# [13,    40] acc: 0.764
# [13,    50] loss: 0.010
# [13,    50] acc: 0.720
# Accuracy of the network on the test images: 81 %
# [13] loss: 0.516
# [13] acc: 81.619
# Validation loss decreased (0.515983 --> 0.515582).  Saving model ...
# Accuracy of the network on the test images: 82 %
# [14,    10] loss: 0.009
# [14,    10] acc: 0.736
# [14,    20] loss: 0.011
# [14,    20] acc: 0.676
# [14,    30] loss: 0.011
# [14,    30] acc: 0.701
# [14,    40] loss: 0.010
# [14,    40] acc: 0.712
# [14,    50] loss: 0.011
# [14,    50] acc: 0.676
# Accuracy of the network on the test images: 79 %
# [14] loss: 0.534
# [14] acc: 79.698
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 83 %
# [15,    10] loss: 0.010
# [15,    10] acc: 0.721
# [15,    20] loss: 0.010
# [15,    20] acc: 0.702
# [15,    30] loss: 0.011
# [15,    30] acc: 0.704
# [15,    40] loss: 0.010
# [15,    40] acc: 0.710
# [15,    50] loss: 0.011
# [15,    50] acc: 0.684
# Accuracy of the network on the test images: 80 %
# [15] loss: 0.536
# [15] acc: 80.933
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 83 %
# [16,    10] loss: 0.008
# [16,    10] acc: 0.745
# [16,    20] loss: 0.010
# [16,    20] acc: 0.716
# [16,    30] loss: 0.012
# [16,    30] acc: 0.678
# [16,    40] loss: 0.010
# [16,    40] acc: 0.723
# [16,    50] loss: 0.010
# [16,    50] acc: 0.745
# Accuracy of the network on the test images: 81 %
# [16] loss: 0.503
# [16] acc: 81.481
# Validation loss decreased (0.515582 --> 0.503328).  Saving model ...
# Accuracy of the network on the test images: 82 %
# [17,    10] loss: 0.011
# [17,    10] acc: 0.698
# [17,    20] loss: 0.010
# [17,    20] acc: 0.690
# [17,    30] loss: 0.011
# [17,    30] acc: 0.670
# [17,    40] loss: 0.010
# [17,    40] acc: 0.704
# [17,    50] loss: 0.010
# [17,    50] acc: 0.703
# Accuracy of the network on the test images: 78 %
# [17] loss: 0.561
# [17] acc: 78.464
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 82 %
# [18,    10] loss: 0.009
# [18,    10] acc: 0.702
# [18,    20] loss: 0.011
# [18,    20] acc: 0.696
# [18,    30] loss: 0.010
# [18,    30] acc: 0.707
# [18,    40] loss: 0.009
# [18,    40] acc: 0.745
# [18,    50] loss: 0.010
# [18,    50] acc: 0.723
# Accuracy of the network on the test images: 81 %
# [18] loss: 0.531
# [18] acc: 81.344
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 82 %
# [19,    10] loss: 0.010
# [19,    10] acc: 0.702
# [19,    20] loss: 0.009
# [19,    20] acc: 0.742
# [19,    30] loss: 0.009
# [19,    30] acc: 0.741
# [19,    40] loss: 0.009
# [19,    40] acc: 0.718
# [19,    50] loss: 0.011
# [19,    50] acc: 0.687
# Accuracy of the network on the test images: 80 %
# [19] loss: 0.552
# [19] acc: 80.247
# EarlyStopping counter: 3 out of 5
# Accuracy of the network on the test images: 82 %
# [20,    10] loss: 0.011
# [20,    10] acc: 0.676
# [20,    20] loss: 0.010
# [20,    20] acc: 0.750
# [20,    30] loss: 0.011
# [20,    30] acc: 0.716
# [20,    40] loss: 0.010
# [20,    40] acc: 0.713
# [20,    50] loss: 0.010
# [20,    50] acc: 0.696
# Accuracy of the network on the test images: 80 %
# [20] loss: 0.524
# [20] acc: 80.933
# EarlyStopping counter: 4 out of 5
# Accuracy of the network on the test images: 83 %
# Finished Training
# Accuracy of the network on the test images: 80 %

# %% [markdown]
# # Second choice of freezing

# %%
model = init_and_freeze('last')
print(summary(model.cuda(), (3, 224, 224)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                 [-1, 1000]       2,049,000
#             ReLU-175                 [-1, 1000]               0
#          Dropout-176                 [-1, 1000]               0
#           Linear-177                    [-1, 4]           4,004
# ================================================================
# Total params: 25,561,036
# Trainable params: 2,053,004
# Non-trainable params: 23,508,032
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.57
# Params size (MB): 97.51
# Estimated Total Size (MB): 384.66
# ----------------------------------------------------------------
# None

# %%
num_epochs = 5
batch_size = 64
learning_rate = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0190110ba462> in <module>
#       5 optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#       6
# ----> 7 train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
#       8 test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)
#
# NameError: name 'training_set' is not defined

# %%
find_lr(model, criterion, optimizer)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#   )
# ) <class 'torchvision.models.resnet.ResNet'>

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 5,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# [1,    10] loss: 0.020
# [1,    10] acc: 0.324
# [1,    20] loss: 0.021
# [1,    20] acc: 0.355
# [1,    30] loss: 0.020
# [1,    30] acc: 0.357
# Accuracy of the network on the test images: 54 %
# [1] loss: 1.206
# [1] acc: 54.321
# Validation loss decreased (inf --> 1.205508).  Saving model ...
# Accuracy of the network on the test images: 44 %
# [2,    10] loss: 0.021
# [2,    10] acc: 0.375
# [2,    20] loss: 0.020
# [2,    20] acc: 0.417
# [2,    30] loss: 0.019
# [2,    30] acc: 0.422
# Accuracy of the network on the test images: 54 %
# [2] loss: 1.178
# [2] acc: 54.458
# Validation loss decreased (1.205508 --> 1.178487).  Saving model ...
# Accuracy of the network on the test images: 45 %
# [3,    10] loss: 0.020
# [3,    10] acc: 0.412
# [3,    20] loss: 0.019
# [3,    20] acc: 0.458
# [3,    30] loss: 0.020
# [3,    30] acc: 0.375
# Accuracy of the network on the test images: 57 %
# [3] loss: 1.138
# [3] acc: 57.064
# Validation loss decreased (1.178487 --> 1.137819).  Saving model ...
# Accuracy of the network on the test images: 46 %
# [4,    10] loss: 0.020
# [4,    10] acc: 0.350
# [4,    20] loss: 0.018
# [4,    20] acc: 0.445
# [4,    30] loss: 0.019
# [4,    30] acc: 0.431
# Accuracy of the network on the test images: 58 %
# [4] loss: 1.063
# [4] acc: 58.848
# Validation loss decreased (1.137819 --> 1.063300).  Saving model ...
# Accuracy of the network on the test images: 47 %
# [5,    10] loss: 0.019
# [5,    10] acc: 0.423
# [5,    20] loss: 0.018
# [5,    20] acc: 0.450
# [5,    30] loss: 0.017
# [5,    30] acc: 0.454
# Accuracy of the network on the test images: 63 %
# [5] loss: 1.008
# [5] acc: 63.649
# Validation loss decreased (1.063300 --> 1.007881).  Saving model ...
# Accuracy of the network on the test images: 51 %
# [6,    10] loss: 0.018
# [6,    10] acc: 0.413
# [6,    20] loss: 0.017
# [6,    20] acc: 0.476
# [6,    30] loss: 0.017
# [6,    30] acc: 0.484
# Accuracy of the network on the test images: 70 %
# [6] loss: 0.971
# [6] acc: 70.645
# Validation loss decreased (1.007881 --> 0.970921).  Saving model ...
# Accuracy of the network on the test images: 55 %
# [7,    10] loss: 0.018
# [7,    10] acc: 0.455
# [7,    20] loss: 0.019
# [7,    20] acc: 0.452
# [7,    30] loss: 0.017
# [7,    30] acc: 0.492
# Accuracy of the network on the test images: 72 %
# [7] loss: 0.935
# [7] acc: 72.977
# Validation loss decreased (0.970921 --> 0.934968).  Saving model ...
# Accuracy of the network on the test images: 57 %
# [8,    10] loss: 0.017
# [8,    10] acc: 0.494
# [8,    20] loss: 0.018
# [8,    20] acc: 0.475
# [8,    30] loss: 0.016
# [8,    30] acc: 0.540
# Accuracy of the network on the test images: 73 %
# [8] loss: 0.916
# [8] acc: 73.663
# Validation loss decreased (0.934968 --> 0.915612).  Saving model ...
# Accuracy of the network on the test images: 58 %
# [9,    10] loss: 0.015
# [9,    10] acc: 0.538
# [9,    20] loss: 0.018
# [9,    20] acc: 0.502
# [9,    30] loss: 0.017
# [9,    30] acc: 0.511
# Accuracy of the network on the test images: 74 %
# [9] loss: 0.880
# [9] acc: 74.348
# Validation loss decreased (0.915612 --> 0.879622).  Saving model ...
# Accuracy of the network on the test images: 59 %
# [10,    10] loss: 0.017
# [10,    10] acc: 0.541
# [10,    20] loss: 0.018
# [10,    20] acc: 0.477
# [10,    30] loss: 0.016
# [10,    30] acc: 0.550
# Accuracy of the network on the test images: 74 %
# [10] loss: 0.875
# [10] acc: 74.211
# Validation loss decreased (0.879622 --> 0.875194).  Saving model ...
# Accuracy of the network on the test images: 61 %
# [11,    10] loss: 0.015
# [11,    10] acc: 0.590
# [11,    20] loss: 0.017
# [11,    20] acc: 0.499
# [11,    30] loss: 0.017
# [11,    30] acc: 0.511
# Accuracy of the network on the test images: 75 %
# [11] loss: 0.854
# [11] acc: 75.171
# Validation loss decreased (0.875194 --> 0.853647).  Saving model ...
# Accuracy of the network on the test images: 62 %
# [12,    10] loss: 0.015
# [12,    10] acc: 0.593
# [12,    20] loss: 0.016
# [12,    20] acc: 0.560
# [12,    30] loss: 0.015
# [12,    30] acc: 0.591
# Accuracy of the network on the test images: 75 %
# [12] loss: 0.857
# [12] acc: 75.309
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 62 %
# [13,    10] loss: 0.017
# [13,    10] acc: 0.509
# [13,    20] loss: 0.016
# [13,    20] acc: 0.555
# [13,    30] loss: 0.014
# [13,    30] acc: 0.624
# Accuracy of the network on the test images: 75 %
# [13] loss: 0.818
# [13] acc: 75.583
# Validation loss decreased (0.853647 --> 0.817990).  Saving model ...
# Accuracy of the network on the test images: 63 %
# [14,    10] loss: 0.015
# [14,    10] acc: 0.569
# [14,    20] loss: 0.016
# [14,    20] acc: 0.524
# [14,    30] loss: 0.015
# [14,    30] acc: 0.572
# Accuracy of the network on the test images: 76 %
# [14] loss: 0.817
# [14] acc: 76.269
# Validation loss decreased (0.817990 --> 0.816749).  Saving model ...
# Accuracy of the network on the test images: 64 %
# [15,    10] loss: 0.015
# [15,    10] acc: 0.609
# [15,    20] loss: 0.014
# [15,    20] acc: 0.615
# [15,    30] loss: 0.015
# [15,    30] acc: 0.577
# Accuracy of the network on the test images: 77 %
# [15] loss: 0.801
# [15] acc: 77.503
# Validation loss decreased (0.816749 --> 0.800746).  Saving model ...
# Accuracy of the network on the test images: 65 %
# [16,    10] loss: 0.015
# [16,    10] acc: 0.577
# [16,    20] loss: 0.014
# [16,    20] acc: 0.619
# [16,    30] loss: 0.015
# [16,    30] acc: 0.579
# Accuracy of the network on the test images: 75 %
# [16] loss: 0.801
# [16] acc: 75.995
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 67 %
# [17,    10] loss: 0.015
# [17,    10] acc: 0.574
# [17,    20] loss: 0.015
# [17,    20] acc: 0.603
# [17,    30] loss: 0.014
# [17,    30] acc: 0.599
# Accuracy of the network on the test images: 76 %
# [17] loss: 0.793
# [17] acc: 76.132
# Validation loss decreased (0.800746 --> 0.792722).  Saving model ...
# Accuracy of the network on the test images: 67 %
# [18,    10] loss: 0.014
# [18,    10] acc: 0.620
# [18,    20] loss: 0.015
# [18,    20] acc: 0.583
# [18,    30] loss: 0.014
# [18,    30] acc: 0.595
# Accuracy of the network on the test images: 76 %
# [18] loss: 0.782
# [18] acc: 76.818
# Validation loss decreased (0.792722 --> 0.782183).  Saving model ...
# Accuracy of the network on the test images: 68 %
# [19,    10] loss: 0.014
# [19,    10] acc: 0.620
# [19,    20] loss: 0.013
# [19,    20] acc: 0.648
# [19,    30] loss: 0.014
# [19,    30] acc: 0.608
# Accuracy of the network on the test images: 76 %
# [19] loss: 0.784
# [19] acc: 76.406
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 69 %
# [20,    10] loss: 0.014
# [20,    10] acc: 0.607
# [20,    20] loss: 0.014
# [20,    20] acc: 0.629
# [20,    30] loss: 0.014
# [20,    30] acc: 0.600
# Accuracy of the network on the test images: 74 %
# [20] loss: 0.788
# [20] acc: 74.623
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 70 %
# Finished Training
# Accuracy of the network on the test images: 74 %

# %% [markdown]
# # Third choice of Freezing

# %%
model = init_and_freeze('2/3')
print(summary(model.cuda(), (3, 224, 224)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                 [-1, 1000]       2,049,000
#             ReLU-175                 [-1, 1000]               0
#          Dropout-176                 [-1, 1000]               0
#           Linear-177                    [-1, 4]           4,004
# ================================================================
# Total params: 25,561,036
# Trainable params: 19,516,812
# Non-trainable params: 6,044,224
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.57
# Params size (MB): 97.51
# Estimated Total Size (MB): 384.66
# ----------------------------------------------------------------
# None

# %%
num_epochs = 5
batch_size = 64
learning_rate = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

# %%
find_lr(model, criterion, optimizer)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#   )
# ) <class 'torchvision.models.resnet.ResNet'>

# %%
learning_rate = 5e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 5,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# [1,    10] loss: 0.037
# [1,    10] acc: 0.210
# [1,    20] loss: 0.022
# [1,    20] acc: 0.291
# [1,    30] loss: 0.019
# [1,    30] acc: 0.297
# Accuracy of the network on the test images: 33 %
# [1] loss: 1.365
# [1] acc: 33.745
# Validation loss decreased (inf --> 1.364823).  Saving model ...
# Accuracy of the network on the test images: 32 %
# [2,    10] loss: 0.019
# [2,    10] acc: 0.298
# [2,    20] loss: 0.020
# [2,    20] acc: 0.354
# [2,    30] loss: 0.019
# [2,    30] acc: 0.360
# Accuracy of the network on the test images: 34 %
# [2] loss: 1.245
# [2] acc: 34.705
# Validation loss decreased (1.364823 --> 1.245132).  Saving model ...
# Accuracy of the network on the test images: 33 %
# [3,    10] loss: 0.019
# [3,    10] acc: 0.312
# [3,    20] loss: 0.019
# [3,    20] acc: 0.317
# [3,    30] loss: 0.019
# [3,    30] acc: 0.351
# Accuracy of the network on the test images: 36 %
# [3] loss: 1.222
# [3] acc: 36.077
# Validation loss decreased (1.245132 --> 1.222048).  Saving model ...
# Accuracy of the network on the test images: 33 %
# [4,    10] loss: 0.018
# [4,    10] acc: 0.399
# [4,    20] loss: 0.019
# [4,    20] acc: 0.378
# [4,    30] loss: 0.018
# [4,    30] acc: 0.463
# Accuracy of the network on the test images: 74 %
# [4] loss: 0.932
# [4] acc: 74.074
# Validation loss decreased (1.222048 --> 0.931712).  Saving model ...
# Accuracy of the network on the test images: 54 %
# [5,    10] loss: 0.017
# [5,    10] acc: 0.465
# [5,    20] loss: 0.017
# [5,    20] acc: 0.475
# [5,    30] loss: 0.018
# [5,    30] acc: 0.506
# Accuracy of the network on the test images: 79 %
# [5] loss: 0.766
# [5] acc: 79.835
# Validation loss decreased (0.931712 --> 0.765893).  Saving model ...
# Accuracy of the network on the test images: 59 %
# [6,    10] loss: 0.016
# [6,    10] acc: 0.538
# [6,    20] loss: 0.014
# [6,    20] acc: 0.626
# [6,    30] loss: 0.016
# [6,    30] acc: 0.530
# Accuracy of the network on the test images: 72 %
# [6] loss: 0.852
# [6] acc: 72.840
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 57 %
# [7,    10] loss: 0.015
# [7,    10] acc: 0.578
# [7,    20] loss: 0.015
# [7,    20] acc: 0.552
# [7,    30] loss: 0.015
# [7,    30] acc: 0.561
# Accuracy of the network on the test images: 78 %
# [7] loss: 0.821
# [7] acc: 78.464
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 64 %
# [8,    10] loss: 0.015
# [8,    10] acc: 0.564
# [8,    20] loss: 0.013
# [8,    20] acc: 0.627
# [8,    30] loss: 0.014
# [8,    30] acc: 0.606
# Accuracy of the network on the test images: 72 %
# [8] loss: 0.760
# [8] acc: 72.016
# Validation loss decreased (0.765893 --> 0.759830).  Saving model ...
# Accuracy of the network on the test images: 65 %
# [9,    10] loss: 0.014
# [9,    10] acc: 0.617
# [9,    20] loss: 0.013
# [9,    20] acc: 0.628
# [9,    30] loss: 0.013
# [9,    30] acc: 0.606
# Accuracy of the network on the test images: 57 %
# [9] loss: 1.084
# [9] acc: 57.064
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 59 %
# [10,    10] loss: 0.010
# [10,    10] acc: 0.721
# [10,    20] loss: 0.012
# [10,    20] acc: 0.650
# [10,    30] loss: 0.014
# [10,    30] acc: 0.541
# Accuracy of the network on the test images: 73 %
# [10] loss: 0.731
# [10] acc: 73.937
# Validation loss decreased (0.759830 --> 0.730712).  Saving model ...
# Accuracy of the network on the test images: 73 %
# [11,    10] loss: 0.011
# [11,    10] acc: 0.640
# [11,    20] loss: 0.008
# [11,    20] acc: 0.769
# [11,    30] loss: 0.010
# [11,    30] acc: 0.695
# Accuracy of the network on the test images: 65 %
# [11] loss: 0.923
# [11] acc: 65.021
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 76 %
# [12,    10] loss: 0.009
# [12,    10] acc: 0.750
# [12,    20] loss: 0.009
# [12,    20] acc: 0.778
# [12,    30] loss: 0.012
# [12,    30] acc: 0.666
# Accuracy of the network on the test images: 58 %
# [12] loss: 1.378
# [12] acc: 58.025
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 66 %
# [13,    10] loss: 0.007
# [13,    10] acc: 0.765
# [13,    20] loss: 0.008
# [13,    20] acc: 0.770
# [13,    30] loss: 0.008
# [13,    30] acc: 0.772
# Accuracy of the network on the test images: 72 %
# [13] loss: 1.268
# [13] acc: 72.154
# EarlyStopping counter: 3 out of 5
# Accuracy of the network on the test images: 79 %
# [14,    10] loss: 0.006
# [14,    10] acc: 0.788
# [14,    20] loss: 0.008
# [14,    20] acc: 0.785
# [14,    30] loss: 0.007
# [14,    30] acc: 0.802
# Accuracy of the network on the test images: 61 %
# [14] loss: 1.281
# [14] acc: 61.317
# EarlyStopping counter: 4 out of 5
# Accuracy of the network on the test images: 76 %
# [15,    10] loss: 0.006
# [15,    10] acc: 0.789
# [15,    20] loss: 0.006
# [15,    20] acc: 0.846
# [15,    30] loss: 0.005
# [15,    30] acc: 0.851
# Accuracy of the network on the test images: 72 %
# [15] loss: 0.962
# [15] acc: 72.565
# EarlyStopping counter: 5 out of 5
# Accuracy of the network on the test images: 90 %
# Early stopping
# Finished Training
# Accuracy of the network on the test images: 73 %

# %% [markdown]
# # Fourth choice of Freezing

# %% [markdown]
# Without weight coefficienting, results were poor, so I directly showed results only with weight coefficienting

# %%
model = init_and_freeze('1/5')
print(summary(model.cuda(), (3, 224, 224)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                 [-1, 1000]       2,049,000
#             ReLU-175                 [-1, 1000]               0
#          Dropout-176                 [-1, 1000]               0
#           Linear-177                    [-1, 4]           4,004
# ================================================================
# Total params: 25,561,036
# Trainable params: 25,336,204
# Non-trainable params: 224,832
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.57
# Params size (MB): 97.51
# Estimated Total Size (MB): 384.66
# ----------------------------------------------------------------
# None

# %%
num_epochs = 5
batch_size = 64
learning_rate = 0.001
class_weights = torch.FloatTensor([1/0.2767, 1/0.0805, 1/0.3263, 1/0.3165]).cuda()
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=False)

# %%
find_lr(model, criterion, optimizer)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#   )
# ) <class 'torchvision.models.resnet.ResNet'>

# %%
learning_rate = 3e-4
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 5,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# [1,    10] loss: 0.897
# [1,    10] acc: 0.301
# [1,    20] loss: 1.032
# [1,    20] acc: 0.332
# [1,    30] loss: 1.017
# [1,    30] acc: 0.295
# Accuracy of the network on the test images: 32 %
# [1] loss: 45.153
# [1] acc: 32.099
# Validation loss decreased (inf --> 45.153033).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [2,    10] loss: 1.077
# [2,    10] acc: 0.297
# [2,    20] loss: 0.887
# [2,    20] acc: 0.305
# [2,    30] loss: 1.734
# [2,    30] acc: 0.318
# Accuracy of the network on the test images: 32 %
# [2] loss: 26.372
# [2] acc: 32.099
# Validation loss decreased (45.153033 --> 26.371782).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [3,    10] loss: 0.805
# [3,    10] acc: 0.321
# [3,    20] loss: 1.056
# [3,    20] acc: 0.286
# [3,    30] loss: 0.667
# [3,    30] acc: 0.292
# Accuracy of the network on the test images: 32 %
# [3] loss: 25.893
# [3] acc: 32.099
# Validation loss decreased (26.371782 --> 25.892885).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [4,    10] loss: 1.158
# [4,    10] acc: 0.263
# [4,    20] loss: 0.883
# [4,    20] acc: 0.306
# [4,    30] loss: 0.798
# [4,    30] acc: 0.290
# Accuracy of the network on the test images: 32 %
# [4] loss: 22.109
# [4] acc: 32.099
# Validation loss decreased (25.892885 --> 22.109455).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [5,    10] loss: 0.749
# [5,    10] acc: 0.255
# [5,    20] loss: 0.607
# [5,    20] acc: 0.290
# [5,    30] loss: 1.061
# [5,    30] acc: 0.327
# Accuracy of the network on the test images: 32 %
# [5] loss: 18.166
# [5] acc: 32.099
# Validation loss decreased (22.109455 --> 18.165996).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [6,    10] loss: 0.459
# [6,    10] acc: 0.307
# [6,    20] loss: 0.780
# [6,    20] acc: 0.255
# [6,    30] loss: 1.118
# [6,    30] acc: 0.297
# Accuracy of the network on the test images: 32 %
# [6] loss: 16.798
# [6] acc: 32.099
# Validation loss decreased (18.165996 --> 16.797867).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [7,    10] loss: 1.091
# [7,    10] acc: 0.265
# [7,    20] loss: 0.609
# [7,    20] acc: 0.345
# [7,    30] loss: 0.531
# [7,    30] acc: 0.311
# Accuracy of the network on the test images: 32 %
# [7] loss: 13.377
# [7] acc: 32.099
# Validation loss decreased (16.797867 --> 13.376989).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [8,    10] loss: 0.563
# [8,    10] acc: 0.305
# [8,    20] loss: 0.606
# [8,    20] acc: 0.281
# [8,    30] loss: 0.593
# [8,    30] acc: 0.272
# Accuracy of the network on the test images: 32 %
# [8] loss: 11.380
# [8] acc: 32.099
# Validation loss decreased (13.376989 --> 11.379522).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [9,    10] loss: 0.711
# [9,    10] acc: 0.286
# [9,    20] loss: 0.481
# [9,    20] acc: 0.285
# [9,    30] loss: 0.412
# [9,    30] acc: 0.299
# Accuracy of the network on the test images: 32 %
# [9] loss: 9.860
# [9] acc: 32.099
# Validation loss decreased (11.379522 --> 9.859969).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [10,    10] loss: 0.367
# [10,    10] acc: 0.298
# [10,    20] loss: 0.625
# [10,    20] acc: 0.309
# [10,    30] loss: 0.533
# [10,    30] acc: 0.280
# Accuracy of the network on the test images: 36 %
# [10] loss: 8.665
# [10] acc: 36.900
# Validation loss decreased (9.859969 --> 8.664523).  Saving model ...
# Accuracy of the network on the test images: 33 %
# [11,    10] loss: 0.354
# [11,    10] acc: 0.287
# [11,    20] loss: 0.899
# [11,    20] acc: 0.305
# [11,    30] loss: 0.382
# [11,    30] acc: 0.256
# Accuracy of the network on the test images: 36 %
# [11] loss: 8.063
# [11] acc: 36.488
# Validation loss decreased (8.664523 --> 8.063486).  Saving model ...
# Accuracy of the network on the test images: 33 %
# [12,    10] loss: 0.337
# [12,    10] acc: 0.274
# [12,    20] loss: 0.317
# [12,    20] acc: 0.355
# [12,    30] loss: 0.391
# [12,    30] acc: 0.294
# Accuracy of the network on the test images: 36 %
# [12] loss: 6.926
# [12] acc: 36.077
# Validation loss decreased (8.063486 --> 6.925720).  Saving model ...
# Accuracy of the network on the test images: 33 %
# [13,    10] loss: 0.413
# [13,    10] acc: 0.297
# [13,    20] loss: 0.583
# [13,    20] acc: 0.292
# [13,    30] loss: 0.297
# [13,    30] acc: 0.260
# Accuracy of the network on the test images: 34 %
# [13] loss: 6.606
# [13] acc: 34.294
# Validation loss decreased (6.925720 --> 6.606382).  Saving model ...
# Accuracy of the network on the test images: 32 %
# [14,    10] loss: 0.322
# [14,    10] acc: 0.282
# [14,    20] loss: 0.481
# [14,    20] acc: 0.251
# [14,    30] loss: 0.395
# [14,    30] acc: 0.244
# Accuracy of the network on the test images: 32 %
# [14] loss: 6.554
# [14] acc: 32.236
# Validation loss decreased (6.606382 --> 6.554294).  Saving model ...
# Accuracy of the network on the test images: 31 %
# [15,    10] loss: 0.261
# [15,    10] acc: 0.294
# [15,    20] loss: 0.220
# [15,    20] acc: 0.255
# [15,    30] loss: 0.397
# [15,    30] acc: 0.263
# Accuracy of the network on the test images: 27 %
# [15] loss: 6.556
# [15] acc: 27.846
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 28 %
# [16,    10] loss: 0.350
# [16,    10] acc: 0.252
# [16,    20] loss: 0.187
# [16,    20] acc: 0.240
# [16,    30] loss: 0.182
# [16,    30] acc: 0.223
# Accuracy of the network on the test images: 25 %
# [16] loss: 6.901
# [16] acc: 25.103
# EarlyStopping counter: 2 out of 5
# Accuracy of the network on the test images: 25 %
# [17,    10] loss: 0.186
# [17,    10] acc: 0.225
# [17,    20] loss: 0.195
# [17,    20] acc: 0.255
# [17,    30] loss: 0.289
# [17,    30] acc: 0.232
# Accuracy of the network on the test images: 25 %
# [17] loss: 6.081
# [17] acc: 25.652
# Validation loss decreased (6.554294 --> 6.080526).  Saving model ...
# Accuracy of the network on the test images: 25 %
# [18,    10] loss: 0.335
# [18,    10] acc: 0.271
# [18,    20] loss: 0.173
# [18,    20] acc: 0.244
# [18,    30] loss: 0.331
# [18,    30] acc: 0.245
# Accuracy of the network on the test images: 20 %
# [18] loss: 6.255
# [18] acc: 20.439
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 19 %
# [19,    10] loss: 0.276
# [19,    10] acc: 0.235
# [19,    20] loss: 0.481
# [19,    20] acc: 0.266
# [19,    30] loss: 0.110
# [19,    30] acc: 0.297
# Accuracy of the network on the test images: 32 %
# [19] loss: 5.406
# [19] acc: 32.647
# Validation loss decreased (6.080526 --> 5.406492).  Saving model ...
# Accuracy of the network on the test images: 29 %
# [20,    10] loss: 0.159
# [20,    10] acc: 0.243
# [20,    20] loss: 0.206
# [20,    20] acc: 0.224
# [20,    30] loss: 0.404
# [20,    30] acc: 0.238
# Accuracy of the network on the test images: 28 %
# [20] loss: 7.133
# [20] acc: 28.258
# EarlyStopping counter: 1 out of 5
# Accuracy of the network on the test images: 24 %
# Finished Training
# Accuracy of the network on the test images: 28 %

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)

# %% [markdown]
# # Fifth choice of Freezing

# %%
model = init_and_freeze('none')

# %%
num_epochs = 5
batch_size = 64
learning_rate = 0.001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

# %%
find_lr(model, criterion, optimizer)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1000, out_features=4, bias=True)
#   )
# ) <class 'torchvision.models.resnet.ResNet'>

# %%
learning_rate = 5e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 30,
      patience = 7,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# [1,    10] loss: 0.020
# [1,    10] acc: 0.368
# [1,    20] loss: 0.020
# [1,    20] acc: 0.419
# [1,    30] loss: 0.019
# [1,    30] acc: 0.491
# Accuracy of the network on the test images: 78 %
# [1] loss: 0.746
# [1] acc: 78.052
# Validation loss decreased (inf --> 0.746265).  Saving model ...
# Accuracy of the network on the test images: 67 %
# [2,    10] loss: 0.012
# [2,    10] acc: 0.679
# [2,    20] loss: 0.011
# [2,    20] acc: 0.687
# [2,    30] loss: 0.012
# [2,    30] acc: 0.631
# Accuracy of the network on the test images: 82 %
# [2] loss: 0.606
# [2] acc: 82.305
# Validation loss decreased (0.746265 --> 0.606204).  Saving model ...
# Accuracy of the network on the test images: 86 %
# [3,    10] loss: 0.007
# [3,    10] acc: 0.788
# [3,    20] loss: 0.007
# [3,    20] acc: 0.819
# [3,    30] loss: 0.007
# [3,    30] acc: 0.818
# Accuracy of the network on the test images: 79 %
# [3] loss: 0.609
# [3] acc: 79.150
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 98 %
# [4,    10] loss: 0.003
# [4,    10] acc: 0.920
# [4,    20] loss: 0.003
# [4,    20] acc: 0.919
# [4,    30] loss: 0.003
# [4,    30] acc: 0.913
# Accuracy of the network on the test images: 79 %
# [4] loss: 0.612
# [4] acc: 79.150
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 99 %
# [5,    10] loss: 0.001
# [5,    10] acc: 0.940
# [5,    20] loss: 0.001
# [5,    20] acc: 0.961
# [5,    30] loss: 0.001
# [5,    30] acc: 0.965
# Accuracy of the network on the test images: 78 %
# [5] loss: 0.609
# [5] acc: 78.738
# EarlyStopping counter: 3 out of 7
# Accuracy of the network on the test images: 99 %
# [6,    10] loss: 0.001
# [6,    10] acc: 0.955
# [6,    20] loss: 0.000
# [6,    20] acc: 0.969
# [6,    30] loss: 0.001
# [6,    30] acc: 0.967
# Accuracy of the network on the test images: 77 %
# [6] loss: 0.627
# [6] acc: 77.778
# EarlyStopping counter: 4 out of 7
# Accuracy of the network on the test images: 99 %
# [7,    10] loss: 0.000
# [7,    10] acc: 0.955
# [7,    20] loss: 0.000
# [7,    20] acc: 0.970
# [7,    30] loss: 0.000
# [7,    30] acc: 0.970
# Accuracy of the network on the test images: 79 %
# [7] loss: 0.646
# [7] acc: 79.012
# EarlyStopping counter: 5 out of 7
# Accuracy of the network on the test images: 99 %
# [8,    10] loss: 0.000
# [8,    10] acc: 0.952
# [8,    20] loss: 0.000
# [8,    20] acc: 0.970
# [8,    30] loss: 0.000
# [8,    30] acc: 0.971
# Accuracy of the network on the test images: 78 %
# [8] loss: 0.648
# [8] acc: 78.464
# EarlyStopping counter: 6 out of 7
# Accuracy of the network on the test images: 99 %
# [9,    10] loss: 0.000
# [9,    10] acc: 0.955
# [9,    20] loss: 0.000
# [9,    20] acc: 0.970
# [9,    30] loss: 0.000
# [9,    30] acc: 0.971
# Accuracy of the network on the test images: 78 %
# [9] loss: 0.654
# [9] acc: 78.601
# EarlyStopping counter: 7 out of 7
# Accuracy of the network on the test images: 100 %
# Early stopping
# Finished Training
# Accuracy of the network on the test images: 82 %

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)

# %% [markdown]
# # Performance on augmented training dataset

# %%
model = init_and_freeze('none')
batch_size = 64
learning_rate = 0.001
# class_weights = torch.FloatTensor([1/0.2767, 1/0.0805, 1/0.3263, 1/0.3165]).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

trset = torch.load(root_dir + "datasets_8")
training_set = tweakedDataset(trset)#, cuda=False)
train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
show_proportion(training_set, testing_set)
# Out:
# Total number of layers: n=163
# Number of layers in classifier: m=4
# Number of layers in backbone: l=159
# Size of training set: 4524
# Size of testing set: 729

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 7,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# [1,    10] loss: 0.018
# [1,    10] acc: 0.597
# [1,    20] loss: 0.010
# [1,    20] acc: 0.766
# [1,    30] loss: 0.009
# [1,    30] acc: 0.784
# [1,    40] loss: 0.007
# [1,    40] acc: 0.831
# [1,    50] loss: 0.007
# [1,    50] acc: 0.819
# [1,    60] loss: 0.006
# [1,    60] acc: 0.841
# [1,    70] loss: 0.008
# [1,    70] acc: 0.797
# Accuracy of the network on the test images: 79 %
# [1] loss: 0.728
# [1] acc: 79.424
# Validation loss decreased (inf --> 0.727925).  Saving model ...
# Accuracy of the network on the test images: 77 %
# [2,    10] loss: 0.006
# [2,    10] acc: 0.828
# [2,    20] loss: 0.006
# [2,    20] acc: 0.833
# [2,    30] loss: 0.005
# [2,    30] acc: 0.866
# [2,    40] loss: 0.004
# [2,    40] acc: 0.885
# [2,    50] loss: 0.006
# [2,    50] acc: 0.857
# [2,    60] loss: 0.006
# [2,    60] acc: 0.831
# [2,    70] loss: 0.005
# [2,    70] acc: 0.884
# Accuracy of the network on the test images: 87 %
# [2] loss: 0.377
# [2] acc: 87.791
# Validation loss decreased (0.727925 --> 0.376976).  Saving model ...
# Accuracy of the network on the test images: 89 %
# [3,    10] loss: 0.004
# [3,    10] acc: 0.865
# [3,    20] loss: 0.004
# [3,    20] acc: 0.882
# [3,    30] loss: 0.005
# [3,    30] acc: 0.854
# [3,    40] loss: 0.004
# [3,    40] acc: 0.897
# [3,    50] loss: 0.005
# [3,    50] acc: 0.867
# [3,    60] loss: 0.005
# [3,    60] acc: 0.871
# [3,    70] loss: 0.004
# [3,    70] acc: 0.899
# Accuracy of the network on the test images: 87 %
# [3] loss: 0.429
# [3] acc: 87.243
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 91 %
# [4,    10] loss: 0.005
# [4,    10] acc: 0.854
# [4,    20] loss: 0.003
# [4,    20] acc: 0.914
# [4,    30] loss: 0.004
# [4,    30] acc: 0.892
# [4,    40] loss: 0.005
# [4,    40] acc: 0.869
# [4,    50] loss: 0.004
# [4,    50] acc: 0.854
# [4,    60] loss: 0.004
# [4,    60] acc: 0.888
# [4,    70] loss: 0.004
# [4,    70] acc: 0.885
# Accuracy of the network on the test images: 82 %
# [4] loss: 0.471
# [4] acc: 82.716
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 81 %
# [5,    10] loss: 0.003
# [5,    10] acc: 0.874
# [5,    20] loss: 0.003
# [5,    20] acc: 0.903
# [5,    30] loss: 0.003
# [5,    30] acc: 0.894
# [5,    40] loss: 0.004
# [5,    40] acc: 0.904
# [5,    50] loss: 0.005
# [5,    50] acc: 0.856
# [5,    60] loss: 0.005
# [5,    60] acc: 0.856
# [5,    70] loss: 0.004
# [5,    70] acc: 0.877
# Accuracy of the network on the test images: 90 %
# [5] loss: 0.395
# [5] acc: 90.261
# EarlyStopping counter: 3 out of 7
# Accuracy of the network on the test images: 94 %
# [6,    10] loss: 0.002
# [6,    10] acc: 0.901
# [6,    20] loss: 0.003
# [6,    20] acc: 0.898
# [6,    30] loss: 0.002
# [6,    30] acc: 0.932
# [6,    40] loss: 0.003
# [6,    40] acc: 0.905
# [6,    50] loss: 0.003
# [6,    50] acc: 0.907
# [6,    60] loss: 0.002
# [6,    60] acc: 0.912
# [6,    70] loss: 0.003
# [6,    70] acc: 0.899
# Accuracy of the network on the test images: 87 %
# [6] loss: 0.544
# [6] acc: 87.654
# EarlyStopping counter: 4 out of 7
# Accuracy of the network on the test images: 91 %
# [7,    10] loss: 0.003
# [7,    10] acc: 0.872
# [7,    20] loss: 0.002
# [7,    20] acc: 0.938
# [7,    30] loss: 0.002
# [7,    30] acc: 0.932
# [7,    40] loss: 0.002
# [7,    40] acc: 0.906
# [7,    50] loss: 0.003
# [7,    50] acc: 0.911
# [7,    60] loss: 0.003
# [7,    60] acc: 0.917
# [7,    70] loss: 0.002
# [7,    70] acc: 0.919
# Accuracy of the network on the test images: 92 %
# [7] loss: 0.368
# [7] acc: 92.318
# Validation loss decreased (0.376976 --> 0.368451).  Saving model ...
# Accuracy of the network on the test images: 95 %
# [8,    10] loss: 0.002
# [8,    10] acc: 0.923
# [8,    20] loss: 0.002
# [8,    20] acc: 0.924
# [8,    30] loss: 0.003
# [8,    30] acc: 0.904
# [8,    40] loss: 0.002
# [8,    40] acc: 0.907
# [8,    50] loss: 0.002
# [8,    50] acc: 0.925
# [8,    60] loss: 0.003
# [8,    60] acc: 0.911
# [8,    70] loss: 0.001
# [8,    70] acc: 0.937
# Accuracy of the network on the test images: 90 %
# [8] loss: 0.363
# [8] acc: 90.535
# Validation loss decreased (0.368451 --> 0.362627).  Saving model ...
# Accuracy of the network on the test images: 95 %
# [9,    10] loss: 0.001
# [9,    10] acc: 0.920
# [9,    20] loss: 0.002
# [9,    20] acc: 0.934
# [9,    30] loss: 0.002
# [9,    30] acc: 0.930
# [9,    40] loss: 0.003
# [9,    40] acc: 0.927
# [9,    50] loss: 0.002
# [9,    50] acc: 0.919
# [9,    60] loss: 0.002
# [9,    60] acc: 0.933
# [9,    70] loss: 0.003
# [9,    70] acc: 0.911
# Accuracy of the network on the test images: 90 %
# [9] loss: 0.546
# [9] acc: 90.261
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 94 %
# [10,    10] loss: 0.002
# [10,    10] acc: 0.922
# [10,    20] loss: 0.001
# [10,    20] acc: 0.930
# [10,    30] loss: 0.001
# [10,    30] acc: 0.939
# [10,    40] loss: 0.002
# [10,    40] acc: 0.920
# [10,    50] loss: 0.003
# [10,    50] acc: 0.916
# [10,    60] loss: 0.002
# [10,    60] acc: 0.934
# [10,    70] loss: 0.002
# [10,    70] acc: 0.922
# Accuracy of the network on the test images: 88 %
# [10] loss: 0.750
# [10] acc: 88.752
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 91 %
# [11,    10] loss: 0.001
# [11,    10] acc: 0.926
# [11,    20] loss: 0.002
# [11,    20] acc: 0.932
# [11,    30] loss: 0.001
# [11,    30] acc: 0.935
# [11,    40] loss: 0.002
# [11,    40] acc: 0.919
# [11,    50] loss: 0.001
# [11,    50] acc: 0.935
# [11,    60] loss: 0.001
# [11,    60] acc: 0.938
# [11,    70] loss: 0.001
# [11,    70] acc: 0.954
# Accuracy of the network on the test images: 87 %
# [11] loss: 0.511
# [11] acc: 87.517
# EarlyStopping counter: 3 out of 7
# Accuracy of the network on the test images: 96 %
# [12,    10] loss: 0.001
# [12,    10] acc: 0.936
# [12,    20] loss: 0.001
# [12,    20] acc: 0.934
# [12,    30] loss: 0.001
# [12,    30] acc: 0.956
# [12,    40] loss: 0.003
# [12,    40] acc: 0.922
# [12,    50] loss: 0.001
# [12,    50] acc: 0.938
# [12,    60] loss: 0.002
# [12,    60] acc: 0.936
# [12,    70] loss: 0.001
# [12,    70] acc: 0.941
# Accuracy of the network on the test images: 91 %
# [12] loss: 0.506
# [12] acc: 91.221
# EarlyStopping counter: 4 out of 7
# Accuracy of the network on the test images: 97 %
# [13,    10] loss: 0.001
# [13,    10] acc: 0.926
# [13,    20] loss: 0.002
# [13,    20] acc: 0.945
# [13,    30] loss: 0.002
# [13,    30] acc: 0.931
# [13,    40] loss: 0.002
# [13,    40] acc: 0.929
# [13,    50] loss: 0.002
# [13,    50] acc: 0.930
# [13,    60] loss: 0.001
# [13,    60] acc: 0.943
# [13,    70] loss: 0.003
# [13,    70] acc: 0.916
# Accuracy of the network on the test images: 87 %
# [13] loss: 0.462
# [13] acc: 87.654
# EarlyStopping counter: 5 out of 7
# Accuracy of the network on the test images: 95 %
# [14,    10] loss: 0.001
# [14,    10] acc: 0.925
# [14,    20] loss: 0.001
# [14,    20] acc: 0.951
# [14,    30] loss: 0.001
# [14,    30] acc: 0.951
# [14,    40] loss: 0.001
# [14,    40] acc: 0.945
# [14,    50] loss: 0.001
# [14,    50] acc: 0.956
# [14,    60] loss: 0.001
# [14,    60] acc: 0.958
# [14,    70] loss: 0.001
# [14,    70] acc: 0.928
# Accuracy of the network on the test images: 89 %
# [14] loss: 0.684
# [14] acc: 89.300
# EarlyStopping counter: 6 out of 7
# Accuracy of the network on the test images: 96 %
# [15,    10] loss: 0.001
# [15,    10] acc: 0.922
# [15,    20] loss: 0.001
# [15,    20] acc: 0.948
# [15,    30] loss: 0.002
# [15,    30] acc: 0.942
# [15,    40] loss: 0.001
# [15,    40] acc: 0.941
# [15,    50] loss: 0.001
# [15,    50] acc: 0.950
# [15,    60] loss: 0.001
# [15,    60] acc: 0.959
# [15,    70] loss: 0.001
# [15,    70] acc: 0.946
# Accuracy of the network on the test images: 90 %
# [15] loss: 0.569
# [15] acc: 90.535
# EarlyStopping counter: 7 out of 7
# Accuracy of the network on the test images: 97 %
# Early stopping
# Finished Training
# Accuracy of the network on the test images: 90 %

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
torch.save(model, 'unweightedresnet50')

# %% [markdown]
# # Weight adaptation

# %%
model = init_and_freeze('none')
batch_size = 8
learning_rate = 0.001
class_weights = torch.FloatTensor([1/0.2767, 1/0.0805, 1/0.3263, 1/0.3165]).cuda()
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

trset = torch.load(root_dir + "datasets_8")
training_set = tweakedDataset(trset)#, cuda=False)
train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
show_proportion(training_set, testing_set)
# Out:
# Size of training set: 4524
# Size of testing set: 729

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 7,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# /anaconda/envs/azureml_py36_pytorch/lib/python3.6/site-packages/matplotlib/axes/_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# [1,    10] loss: 0.017
# [1,    10] acc: 0.525
# [1,    20] loss: 0.015
# [1,    20] acc: 0.653
# [1,    30] loss: 0.015
# [1,    30] acc: 0.610
# [1,    40] loss: 0.015
# [1,    40] acc: 0.679
# [1,    50] loss: 0.013
# [1,    50] acc: 0.764
# [1,    60] loss: 0.012
# [1,    60] acc: 0.683
# [1,    70] loss: 0.012
# [1,    70] acc: 0.715
# Accuracy of the network on the test images: 80 %
# [1] loss: 0.682
# [1] acc: 80.796
# Validation loss decreased (inf --> 0.682336).  Saving model ...
# Accuracy of the network on the test images: 80 %
# [2,    10] loss: 0.007
# [2,    10] acc: 0.799
# [2,    20] loss: 0.011
# [2,    20] acc: 0.753
# [2,    30] loss: 0.009
# [2,    30] acc: 0.792
# [2,    40] loss: 0.008
# [2,    40] acc: 0.807
# [2,    50] loss: 0.008
# [2,    50] acc: 0.834
# [2,    60] loss: 0.009
# [2,    60] acc: 0.760
# [2,    70] loss: 0.007
# [2,    70] acc: 0.840
# Accuracy of the network on the test images: 79 %
# [2] loss: 0.612
# [2] acc: 79.698
# Validation loss decreased (0.682336 --> 0.612425).  Saving model ...
# Accuracy of the network on the test images: 84 %
# [3,    10] loss: 0.006
# [3,    10] acc: 0.844
# [3,    20] loss: 0.006
# [3,    20] acc: 0.846
# [3,    30] loss: 0.007
# [3,    30] acc: 0.818
# [3,    40] loss: 0.007
# [3,    40] acc: 0.854
# [3,    50] loss: 0.008
# [3,    50] acc: 0.816
# [3,    60] loss: 0.005
# [3,    60] acc: 0.856
# [3,    70] loss: 0.005
# [3,    70] acc: 0.863
# Accuracy of the network on the test images: 84 %
# [3] loss: 0.438
# [3] acc: 84.225
# Validation loss decreased (0.612425 --> 0.437524).  Saving model ...
# Accuracy of the network on the test images: 87 %
# [4,    10] loss: 0.005
# [4,    10] acc: 0.868
# [4,    20] loss: 0.003
# [4,    20] acc: 0.918
# [4,    30] loss: 0.006
# [4,    30] acc: 0.839
# [4,    40] loss: 0.007
# [4,    40] acc: 0.859
# [4,    50] loss: 0.007
# [4,    50] acc: 0.814
# [4,    60] loss: 0.007
# [4,    60] acc: 0.865
# [4,    70] loss: 0.005
# [4,    70] acc: 0.853
# Accuracy of the network on the test images: 85 %
# [4] loss: 0.461
# [4] acc: 85.048
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 89 %
# [5,    10] loss: 0.009
# [5,    10] acc: 0.804
# [5,    20] loss: 0.006
# [5,    20] acc: 0.857
# [5,    30] loss: 0.004
# [5,    30] acc: 0.907
# [5,    40] loss: 0.005
# [5,    40] acc: 0.890
# [5,    50] loss: 0.005
# [5,    50] acc: 0.867
# [5,    60] loss: 0.003
# [5,    60] acc: 0.916
# [5,    70] loss: 0.005
# [5,    70] acc: 0.905
# Accuracy of the network on the test images: 80 %
# [5] loss: 0.630
# [5] acc: 80.110
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 88 %
# [6,    10] loss: 0.003
# [6,    10] acc: 0.896
# [6,    20] loss: 0.003
# [6,    20] acc: 0.905
# [6,    30] loss: 0.003
# [6,    30] acc: 0.907
# [6,    40] loss: 0.006
# [6,    40] acc: 0.888
# [6,    50] loss: 0.004
# [6,    50] acc: 0.863
# [6,    60] loss: 0.004
# [6,    60] acc: 0.911
# [6,    70] loss: 0.003
# [6,    70] acc: 0.905
# Accuracy of the network on the test images: 85 %
# [6] loss: 0.459
# [6] acc: 85.185
# EarlyStopping counter: 3 out of 7
# Accuracy of the network on the test images: 92 %
# [7,    10] loss: 0.004
# [7,    10] acc: 0.896
# [7,    20] loss: 0.004
# [7,    20] acc: 0.889
# [7,    30] loss: 0.005
# [7,    30] acc: 0.894
# [7,    40] loss: 0.003
# [7,    40] acc: 0.890
# [7,    50] loss: 0.004
# [7,    50] acc: 0.893
# [7,    60] loss: 0.004
# [7,    60] acc: 0.893
# [7,    70] loss: 0.003
# [7,    70] acc: 0.929
# Accuracy of the network on the test images: 86 %
# [7] loss: 0.460
# [7] acc: 86.145
# EarlyStopping counter: 4 out of 7
# Accuracy of the network on the test images: 91 %
# [8,    10] loss: 0.003
# [8,    10] acc: 0.884
# [8,    20] loss: 0.003
# [8,    20] acc: 0.910
# [8,    30] loss: 0.002
# [8,    30] acc: 0.920
# [8,    40] loss: 0.004
# [8,    40] acc: 0.883
# [8,    50] loss: 0.003
# [8,    50] acc: 0.923
# [8,    60] loss: 0.004
# [8,    60] acc: 0.898
# [8,    70] loss: 0.003
# [8,    70] acc: 0.921
# Accuracy of the network on the test images: 84 %
# [8] loss: 0.512
# [8] acc: 84.911
# EarlyStopping counter: 5 out of 7
# Accuracy of the network on the test images: 94 %
# [9,    10] loss: 0.002
# [9,    10] acc: 0.915
# [9,    20] loss: 0.003
# [9,    20] acc: 0.928
# [9,    30] loss: 0.003
# [9,    30] acc: 0.907
# [9,    40] loss: 0.005
# [9,    40] acc: 0.865
# [9,    50] loss: 0.003
# [9,    50] acc: 0.910
# [9,    60] loss: 0.003
# [9,    60] acc: 0.906
# [9,    70] loss: 0.005
# [9,    70] acc: 0.916
# Accuracy of the network on the test images: 82 %
# [9] loss: 0.587
# [9] acc: 82.990
# EarlyStopping counter: 6 out of 7
# Accuracy of the network on the test images: 92 %
# [10,    10] loss: 0.002
# [10,    10] acc: 0.917
# [10,    20] loss: 0.001
# [10,    20] acc: 0.950
# [10,    30] loss: 0.004
# [10,    30] acc: 0.906
# [10,    40] loss: 0.002
# [10,    40] acc: 0.913
# [10,    50] loss: 0.002
# [10,    50] acc: 0.937
# [10,    60] loss: 0.002
# [10,    60] acc: 0.922
# [10,    70] loss: 0.003
# [10,    70] acc: 0.900
# Accuracy of the network on the test images: 77 %
# [10] loss: 0.744
# [10] acc: 77.229
# EarlyStopping counter: 7 out of 7
# Accuracy of the network on the test images: 88 %
# Early stopping
# Finished Training
# Accuracy of the network on the test images: 84 %

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
# Out:
# <All keys matched successfully>

# %%
torch.save(model, 'weightedresnet50')

# %% [markdown]
# # Performance on augmented training dataset 2

# %% [markdown]
# We tested on a different dataset: dataset 4. It is smaller than the previous, but more balanced.

# %%
model = init_and_freeze('none')
batch_size = 64
learning_rate = 0.001
# class_weights = torch.FloatTensor([1/0.2356, 1/0.2033, 1/0.2835, 1/0.2775]).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

trset = torch.load(root_dir + "dataset_4")
training_set = tweakedDataset(trset)#, cuda=False)
train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
show_proportion(training_set, testing_set)
# Out:
# Size of training set: 3344
# Size of testing set: 729

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 7,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-17bb15bfdf1a> in <module>
#       3       patience = 7,
#       4       train_acc_period = 10,
# ----> 5       test_acc_period = 1)
#       6 accuracy(model, test_loader, cuda=True)
#       7 plot(loss_train, acc_train, loss_test, acc_test)
#
# <ipython-input-17-0d72f667498f> in smartrain(net, optimizer, train_loader, test_loader, loss, n_epoch, train_acc_period, test_acc_period, cuda, patience)
#     137           # forward + backward + optimize
#     138           outputs = net(inputs)
# --> 139           target = torch.argmax(labels, dim=1)
#     140 #           loss = criterion(outputs, labels)
#     141           loss = criterion(outputs, target)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)

# %% [markdown]
# # Weight adaptation

# %%
model = init_and_freeze('none')
batch_size = 16
learning_rate = 0.001
class_weights = torch.FloatTensor([1/0.2356, 1/0.2033, 1/0.2835, 1/0.2775]).cuda()
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

test_loader = torch.utils.data.DataLoader(testing_set,batch_size=1, shuffle=True)

trset = torch.load(root_dir + "dataset_4")
training_set = tweakedDataset(trset)#, cuda=False)
train_loader = torch.utils.data.DataLoader(training_set,batch_size=batch_size, shuffle=True)
show_proportion(training_set, testing_set)
# Out:
# Size of training set: 3344
# Size of testing set: 729

# %%
model.cuda()
loss_train, acc_train, loss_test, acc_test = smartrain(model, optimizer, train_loader, test_loader, criterion,  n_epoch = 20,
      patience = 7,
      train_acc_period = 10,
      test_acc_period = 1)
accuracy(model, test_loader, cuda=True)
plot(loss_train, acc_train, loss_test, acc_test)
# Out:
# [1,    10] loss: 0.023
# [1,    10] acc: 0.404
# [1,    20] loss: 0.015
# [1,    20] acc: 0.607
# [1,    30] loss: 0.013
# [1,    30] acc: 0.616
# [1,    40] loss: 0.011
# [1,    40] acc: 0.681
# [1,    50] loss: 0.011
# [1,    50] acc: 0.692
# Accuracy of the network on the test images: 75 %
# [1] loss: 0.815
# [1] acc: 75.034
# Validation loss decreased (inf --> 0.814976).  Saving model ...
# Accuracy of the network on the test images: 63 %
# [2,    10] loss: 0.012
# [2,    10] acc: 0.682
# [2,    20] loss: 0.013
# [2,    20] acc: 0.729
# [2,    30] loss: 0.010
# [2,    30] acc: 0.712
# [2,    40] loss: 0.011
# [2,    40] acc: 0.704
# [2,    50] loss: 0.008
# [2,    50] acc: 0.806
# Accuracy of the network on the test images: 63 %
# [2] loss: 1.031
# [2] acc: 63.786
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 62 %
# [3,    10] loss: 0.009
# [3,    10] acc: 0.784
# [3,    20] loss: 0.008
# [3,    20] acc: 0.782
# [3,    30] loss: 0.008
# [3,    30] acc: 0.787
# [3,    40] loss: 0.007
# [3,    40] acc: 0.797
# [3,    50] loss: 0.005
# [3,    50] acc: 0.848
# Accuracy of the network on the test images: 89 %
# [3] loss: 0.299
# [3] acc: 89.438
# Validation loss decreased (0.814976 --> 0.298854).  Saving model ...
# Accuracy of the network on the test images: 88 %
# [4,    10] loss: 0.005
# [4,    10] acc: 0.862
# [4,    20] loss: 0.004
# [4,    20] acc: 0.871
# [4,    30] loss: 0.006
# [4,    30] acc: 0.825
# [4,    40] loss: 0.006
# [4,    40] acc: 0.846
# [4,    50] loss: 0.005
# [4,    50] acc: 0.829
# Accuracy of the network on the test images: 90 %
# [4] loss: 0.273
# [4] acc: 90.947
# Validation loss decreased (0.298854 --> 0.272957).  Saving model ...
# Accuracy of the network on the test images: 88 %
# [5,    10] loss: 0.006
# [5,    10] acc: 0.818
# [5,    20] loss: 0.005
# [5,    20] acc: 0.861
# [5,    30] loss: 0.004
# [5,    30] acc: 0.872
# [5,    40] loss: 0.005
# [5,    40] acc: 0.863
# [5,    50] loss: 0.006
# [5,    50] acc: 0.832
# Accuracy of the network on the test images: 69 %
# [5] loss: 0.883
# [5] acc: 69.822
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 72 %
# [6,    10] loss: 0.004
# [6,    10] acc: 0.871
# [6,    20] loss: 0.005
# [6,    20] acc: 0.868
# [6,    30] loss: 0.004
# [6,    30] acc: 0.897
# [6,    40] loss: 0.005
# [6,    40] acc: 0.850
# [6,    50] loss: 0.004
# [6,    50] acc: 0.848
# Accuracy of the network on the test images: 92 %
# [6] loss: 0.246
# [6] acc: 92.318
# Validation loss decreased (0.272957 --> 0.245575).  Saving model ...
# Accuracy of the network on the test images: 90 %
# [7,    10] loss: 0.004
# [7,    10] acc: 0.884
# [7,    20] loss: 0.002
# [7,    20] acc: 0.934
# [7,    30] loss: 0.004
# [7,    30] acc: 0.875
# [7,    40] loss: 0.004
# [7,    40] acc: 0.891
# [7,    50] loss: 0.004
# [7,    50] acc: 0.894
# Accuracy of the network on the test images: 92 %
# [7] loss: 0.275
# [7] acc: 92.318
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 90 %
# [8,    10] loss: 0.002
# [8,    10] acc: 0.906
# [8,    20] loss: 0.002
# [8,    20] acc: 0.929
# [8,    30] loss: 0.002
# [8,    30] acc: 0.927
# [8,    40] loss: 0.002
# [8,    40] acc: 0.927
# [8,    50] loss: 0.003
# [8,    50] acc: 0.891
# Accuracy of the network on the test images: 91 %
# [8] loss: 0.249
# [8] acc: 91.907
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 92 %
# [9,    10] loss: 0.003
# [9,    10] acc: 0.891
# [9,    20] loss: 0.002
# [9,    20] acc: 0.928
# [9,    30] loss: 0.002
# [9,    30] acc: 0.923
# [9,    40] loss: 0.002
# [9,    40] acc: 0.920
# [9,    50] loss: 0.002
# [9,    50] acc: 0.921
# Accuracy of the network on the test images: 94 %
# [9] loss: 0.230
# [9] acc: 94.239
# Validation loss decreased (0.245575 --> 0.229841).  Saving model ...
# Accuracy of the network on the test images: 96 %
# [10,    10] loss: 0.008
# [10,    10] acc: 0.795
# [10,    20] loss: 0.006
# [10,    20] acc: 0.863
# [10,    30] loss: 0.004
# [10,    30] acc: 0.890
# [10,    40] loss: 0.004
# [10,    40] acc: 0.873
# [10,    50] loss: 0.003
# [10,    50] acc: 0.879
# Accuracy of the network on the test images: 92 %
# [10] loss: 0.213
# [10] acc: 92.730
# Validation loss decreased (0.229841 --> 0.213104).  Saving model ...
# Accuracy of the network on the test images: 94 %
# [11,    10] loss: 0.002
# [11,    10] acc: 0.911
# [11,    20] loss: 0.002
# [11,    20] acc: 0.927
# [11,    30] loss: 0.002
# [11,    30] acc: 0.928
# [11,    40] loss: 0.002
# [11,    40] acc: 0.947
# [11,    50] loss: 0.002
# [11,    50] acc: 0.933
# Accuracy of the network on the test images: 93 %
# [11] loss: 0.260
# [11] acc: 93.827
# EarlyStopping counter: 1 out of 7
# Accuracy of the network on the test images: 97 %
# [12,    10] loss: 0.002
# [12,    10] acc: 0.906
# [12,    20] loss: 0.002
# [12,    20] acc: 0.939
# [12,    30] loss: 0.004
# [12,    30] acc: 0.858
# [12,    40] loss: 0.003
# [12,    40] acc: 0.906
# [12,    50] loss: 0.003
# [12,    50] acc: 0.904
# Accuracy of the network on the test images: 93 %
# [12] loss: 0.223
# [12] acc: 93.827
# EarlyStopping counter: 2 out of 7
# Accuracy of the network on the test images: 94 %
# [13,    10] loss: 0.002
# [13,    10] acc: 0.903
# [13,    20] loss: 0.002
# [13,    20] acc: 0.939
# [13,    30] loss: 0.002
# [13,    30] acc: 0.943
# [13,    40] loss: 0.002
# [13,    40] acc: 0.933
# [13,    50] loss: 0.001
# [13,    50] acc: 0.946
# Accuracy of the network on the test images: 81 %
# [13] loss: 0.701
# [13] acc: 81.070
# EarlyStopping counter: 3 out of 7
# Accuracy of the network on the test images: 83 %
# [14,    10] loss: 0.001
# [14,    10] acc: 0.925
# [14,    20] loss: 0.001
# [14,    20] acc: 0.937
# [14,    30] loss: 0.002
# [14,    30] acc: 0.941
# [14,    40] loss: 0.002
# [14,    40] acc: 0.934
# [14,    50] loss: 0.001
# [14,    50] acc: 0.941
# Accuracy of the network on the test images: 80 %
# [14] loss: 0.590
# [14] acc: 80.384
# EarlyStopping counter: 4 out of 7
# Accuracy of the network on the test images: 79 %
# [15,    10] loss: 0.004
# [15,    10] acc: 0.878
# [15,    20] loss: 0.003
# [15,    20] acc: 0.900
# [15,    30] loss: 0.002
# [15,    30] acc: 0.920
# [15,    40] loss: 0.002
# [15,    40] acc: 0.939
# [15,    50] loss: 0.001
# [15,    50] acc: 0.942
# Accuracy of the network on the test images: 90 %
# [15] loss: 0.295
# [15] acc: 90.947
# EarlyStopping counter: 5 out of 7
# Accuracy of the network on the test images: 96 %
# [16,    10] loss: 0.001
# [16,    10] acc: 0.940
# [16,    20] loss: 0.001
# [16,    20] acc: 0.956
# [16,    30] loss: 0.001
# [16,    30] acc: 0.960
# [16,    40] loss: 0.002
# [16,    40] acc: 0.929
# [16,    50] loss: 0.001
# [16,    50] acc: 0.954
# Accuracy of the network on the test images: 93 %
# [16] loss: 0.238
# [16] acc: 93.416
# EarlyStopping counter: 6 out of 7
# Accuracy of the network on the test images: 97 %
# [17,    10] loss: 0.002
# [17,    10] acc: 0.919
# [17,    20] loss: 0.002
# [17,    20] acc: 0.933
# [17,    30] loss: 0.001
# [17,    30] acc: 0.961
# [17,    40] loss: 0.001
# [17,    40] acc: 0.953
# [17,    50] loss: 0.001
# [17,    50] acc: 0.936
# Accuracy of the network on the test images: 90 %
# [17] loss: 0.314
# [17] acc: 90.123
# EarlyStopping counter: 7 out of 7
# Accuracy of the network on the test images: 93 %
# Early stopping
# Finished Training
# Accuracy of the network on the test images: 92 %

# %%
model.load_state_dict(torch.load('resnet50checkpoint.pt'))
confusion_matrix(model.cuda(), train_loader, size = 4, name = "Train", cuda = True)

# %%
confusion_matrix(model, test_loader, size = 4, name = "Test", cuda = True)
